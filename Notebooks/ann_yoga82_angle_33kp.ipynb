# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
import keras
import librosa
from librosa import display
# %matplotlib inline

# %%
import math
def calculateAngle(x1,y1,x2,y2,x3,y3):
 
    # Calculate the angle between the three points
    angle = math.degrees(math.atan2(y3 - y2, x3 - x2) - math.atan2(y1 - y2, x1 - x2))
    
    if angle<0:
        angle += 360
    
    return angle

# %%
# !pip install -q mediapipe

# %%
import mediapipe as mp

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

def add_angle_feature(df):
    # Define arrays to store the angles
    left_elbow_angles = np.zeros((len(df),))
    right_elbow_angles = np.zeros((len(df),))
    left_shoulder_angles = np.zeros((len(df),))
    right_shoulder_angles = np.zeros((len(df),))
    left_hip_angles = np.zeros((len(df),))
    right_hip_angles = np.zeros((len(df),))
    left_knee_angles = np.zeros((len(df),))
    right_knee_angles = np.zeros((len(df),))

    # Loop through the rows and calculate the angles
    for i in range(len(df)):

        # Calculate left elbow angle
        left_elbow_angles[i] = calculateAngle(df.LEFT_SHOULDER_x[i], 
                                              df.LEFT_SHOULDER_y[i],
                                              df.LEFT_ELBOW_x[i], 
                                              df.LEFT_ELBOW_y[i],
                                              df.LEFT_WRIST_x[i], 
                                              df.LEFT_WRIST_y[i])

        # Calculate right elbow angle
        right_elbow_angles[i] = calculateAngle(df.RIGHT_SHOULDER_x[i], 
                                               df.RIGHT_SHOULDER_y[i],
                                               df.RIGHT_ELBOW_x[i], 
                                               df.RIGHT_ELBOW_y[i],
                                               df.RIGHT_WRIST_x[i], 
                                               df.RIGHT_WRIST_y[i])

        # Calculate left shoulder angle
        left_shoulder_angles[i] = calculateAngle(df.LEFT_HIP_x[i], 
                                                 df.LEFT_HIP_y[i],
                                                 df.LEFT_SHOULDER_x[i], 
                                                 df.LEFT_SHOULDER_y[i],
                                                 df.LEFT_ELBOW_x[i], 
                                                 df.LEFT_ELBOW_y[i])

        # Calculate right shoulder angle
        right_shoulder_angles[i] = calculateAngle(df.RIGHT_HIP_x[i], 
                                                  df.RIGHT_HIP_y[i],
                                                  df.RIGHT_SHOULDER_x[i], 
                                                  df.RIGHT_SHOULDER_y[i],
                                                  df.RIGHT_ELBOW_x[i], 
                                                  df.RIGHT_ELBOW_y[i])

        # Calculate left hip angle
        left_hip_angles[i] = calculateAngle(df.LEFT_SHOULDER_x[i], 
                                            df.LEFT_SHOULDER_y[i],
                                            df.LEFT_HIP_x[i], 
                                            df.LEFT_HIP_y[i],
                                            df.LEFT_KNEE_x[i], 
                                            df.LEFT_KNEE_y[i])

        # Calculate right hip angle
        right_hip_angles[i] = calculateAngle(df.RIGHT_SHOULDER_x[i], 
                                             df.RIGHT_SHOULDER_y[i],
                                             df.RIGHT_HIP_x[i], 
                                             df.RIGHT_HIP_y[i],
                                             df.RIGHT_KNEE_x[i], 
                                             df.RIGHT_KNEE_y[i])

        # Calculate left knee angle
        left_knee_angles[i] = calculateAngle(df.LEFT_HIP_x[i], 
                                             df.LEFT_HIP_y[i],
                                             df.LEFT_KNEE_x[i], 
                                             df.LEFT_KNEE_y[i],
                                             df.LEFT_ANKLE_x[i], 
                                             df.LEFT_ANKLE_y[i])

        # Calculate right knee angle
        right_knee_angles[i] = calculateAngle(df.RIGHT_HIP_x[i], 
                                              df.RIGHT_HIP_y[i],
                                              df.RIGHT_KNEE_x[i], 
                                              df.RIGHT_KNEE_y[i],
                                              df.RIGHT_ANKLE_x[i], 
                                              df.RIGHT_ANKLE_y[i])
    df['left_elbow_angle'] = left_elbow_angles
    df['right_elbow_angle'] = right_elbow_angles
    df['left_shoulder_angle'] = left_shoulder_angles
    df['right_shoulder_angle'] = right_shoulder_angles
    df['left_hip_angle'] = left_hip_angles
    df['right_hip_angle'] = right_hip_angles
    df['left_knee_angle'] = left_knee_angles
    df['right_knee_angle'] = right_knee_angles

    return df

# %%
train = pd.read_csv("/content/drive/MyDrive/UGP23/dataset/Yoga_82_modified/yoga_82/train_keypoints_yoga82.csv")

# %%
# left_elbow_angles of 1st row
calculateAngle(train.LEFT_SHOULDER_x[0],
               train.LEFT_SHOULDER_y[0],
               train.LEFT_ELBOW_x[0],
               train.LEFT_ELBOW_y[0],
               train.LEFT_WRIST_x[0],
               train.LEFT_WRIST_y[0],
               )
# Out:
# 79.58818594849835

# %%
train = add_angle_feature(train)
train
# Out:
#       file_name  labels    NOSE_x    NOSE_y  NOSE_score  LEFT_EYE_INNER_x  \
# 0       631.jpg       5  0.692113  0.597546    0.998951          0.704426
# 1      1_12.jpg       4  0.315723  0.292811    0.999945          0.323114
# 2       189.jpg       3  0.569304  0.255873    1.000000          0.571277
# 3     2_400.jpg       4  0.805867  0.212494    0.999709          0.781934
# 4       216.jpg       7  0.489411  0.177114    0.999858          0.496048
# ...         ...     ...       ...       ...         ...               ...
# 1497     89.jpg       2  0.525786  0.137871    1.000000          0.522916
# 1498  1_122.jpg       1  0.414844  0.212979    0.999174          0.399074
# 1499    274.jpg       8  0.408738  0.684995    0.989426          0.384826
# 1500     29.jpg       5  0.287048  0.326413    0.996459          0.279381
# 1501  1_208.jpg       4  0.229601  0.444994    0.987700          0.206205
#
#       LEFT_EYE_INNER_y  LEFT_EYE_INNER_score  LEFT_EYE_x  LEFT_EYE_y  ...  \
# 0             0.605220              0.998914    0.706371    0.602952  ...
# 1             0.264584              0.999853    0.325839    0.264922  ...
# 2             0.241736              1.000000    0.575188    0.241371  ...
# 3             0.197481              0.998244    0.778692    0.200673  ...
# 4             0.160088              0.999776    0.501392    0.160482  ...
# ...                ...                   ...         ...         ...  ...
# 1497          0.124028              1.000000    0.523098    0.123896  ...
# 1498          0.208266              0.999027    0.397074    0.210901  ...
# 1499          0.691994              0.981414    0.382036    0.688628  ...
# 1500          0.322492              0.993156    0.278479    0.326426  ...
# 1501          0.447745              0.961056    0.203625    0.442314  ...
#
#       RIGHT_FOOT_INDEX_y  RIGHT_FOOT_INDEX_score  left_elbow_angle  \
# 0               0.597948                0.972374         79.588186
# 1               0.807028                0.892986        187.292986
# 2               0.744183                0.999627        179.187971
# 3               0.902261                0.999369        175.364693
# 4               0.928743                0.821828        328.495242
# ...                  ...                     ...               ...
# 1497            0.204772                0.999346        169.199016
# 1498            0.850410                0.945645        164.237805
# 1499            0.765644                0.026248        196.828618
# 1500            0.593082                0.538932        178.369204
# 1501            0.837433                0.046333        189.816382
#
#       right_elbow_angle  left_shoulder_angle  right_shoulder_angle  \
# 0             56.179817           285.263721            288.782246
# 1            185.674594            61.428676             60.346734
# 2            171.981247            75.820600            273.960310
# 3            171.272051           297.058820            297.335670
# 4             39.799935           353.786899             18.808341
# ...                 ...                  ...                   ...
# 1497         189.571555           242.994843             99.832748
# 1498         162.556291           159.884158            159.767588
# 1499         197.519170           174.501520            173.744721
# 1500         186.063438           348.402786             28.504035
# 1501         188.994361            92.895450             94.025811
#
#       left_hip_angle  right_hip_angle  left_knee_angle  right_knee_angle
# 0          72.917352        68.186869       301.697910        302.790281
# 1         248.643596       250.424146        80.064990         76.665754
# 2         214.576236       134.943301       184.964031        218.753930
# 3         113.860182       110.315821       267.071545        271.659420
# 4         124.090971       183.730097       322.191657        184.611325
# ...              ...              ...              ...               ...
# 1497      173.126097       309.480163       180.672061        186.877530
# 1498      231.524579       103.222736       186.351321        275.516546
# 1499      300.228057       296.115081       181.315225        186.560127
# 1500      225.629117       185.456912       317.929158        185.914284
# 1501      269.452529       270.799173        91.567490         92.275057
#
# [1502 rows x 109 columns]

# %%
train.labels.value_counts()
# Out:
# 6    274
# 4    240
# 8    189
# 3    162
# 5    158
# 7    135
# 2    123
# 1    111
# 0    110
# Name: labels, dtype: int64

# %%
x_train = train.drop(['file_name', 'labels'], axis=1)
y_train = train.labels

# %%
y_train = y_train.astype('float64')

# %%
y_train = keras.utils.to_categorical(y_train)

# %%
test = pd.read_csv("/content/drive/MyDrive/UGP23/dataset/Yoga_82_modified/yoga_82/test_keypoints_yoga82.csv")

# %%
test = add_angle_feature(test)

# %%
test.labels.value_counts()
# Out:
# 6    69
# 4    60
# 8    47
# 5    40
# 3    40
# 7    34
# 2    31
# 0    28
# 1    27
# Name: labels, dtype: int64

# %%
x_test = test.drop(['file_name', 'labels'], axis=1)
y_test = test.labels

# %%
y_test = test.labels.astype('float64')

# %%
y_test = keras.utils.to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Dense,Dropout,Activation
from sklearn import metrics
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1201, 107)
# (1201, 9)
# (376, 107)
# (376, 9)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(107,)))
model.add(Dropout(0.25))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(9, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               13824
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 256)               33024
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 64)                16448
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 63,881
# Trainable params: 63,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint_path = "/content/drive/MyDrive/UGP23/dataset/Yoga_82_modified/weights_yoga82_angle&33kp.best_ann.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=100)

# %%
history = model.fit(x_train, y_train, epochs=300, batch_size = 32, validation_data=(x_val, y_val), callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/300
# 28/38 [=====================>........] - ETA: 0s - loss: 20.7484 - accuracy: 0.1529
# Epoch 1: val_accuracy improved from -inf to 0.20266, saving model to /content/drive/MyDrive/UGP23/dataset/Yoga_82_modified/weights_yoga82_angle&33kp.best_ann.hdf5
# 38/38 [==============================] - 1s 8ms/step - loss: 17.0812 - accuracy: 0.1624 - val_loss: 2.0231 - val_accuracy: 0.2027
# Epoch 2/300
# 30/38 [======================>.......] - ETA: 0s - loss: 3.4207 - accuracy: 0.1844
# Epoch 2: val_accuracy improved from 0.20266 to 0.22259, saving model to /content/drive/MyDrive/UGP23/dataset/Yoga_82_modified/weights_yoga82_angle&33kp.best_ann.hdf5
# 38/38 [==============================] - 0s
val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9634 - val_loss: 1.1426 - val_accuracy: 0.8970
# Epoch 293/300
# 25/38 [==================>...........] - ETA: 0s - loss: 0.0970 - accuracy: 0.9663
# Epoch 293: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9659 - val_loss: 1.2025 - val_accuracy: 0.8970
# Epoch 294/300
# 17/38 [============>.................] - ETA: 0s - loss: 0.1587 - accuracy: 0.9577
# Epoch 294: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9525 - val_loss: 1.1197 - val_accuracy: 0.8937
# Epoch 295/300
# 26/38 [===================>..........] - ETA: 0s - loss: 0.1393 - accuracy: 0.9627
# Epoch 295: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9634 - val_loss: 1.0194 - val_accuracy: 0.9003
# Epoch 296/300
# 26/38 [===================>..........] - ETA: 0s - loss: 0.1360 - accuracy: 0.9519
# Epoch 296: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1408 - accuracy: 0.9542 - val_loss: 1.0518 - val_accuracy: 0.8970
# Epoch 297/300
# 24/38 [=================>............] - ETA: 0s - loss: 0.1304 - accuracy: 0.9635
# Epoch 297: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9675 - val_loss: 1.0781 - val_accuracy: 0.9003
# Epoch 298/300
# 25/38 [==================>...........] - ETA: 0s - loss: 0.1462 - accuracy: 0.9600
# Epoch 298: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1331 - accuracy: 0.9600 - val_loss: 1.1520 - val_accuracy: 0.8870
# Epoch 299/300
# 19/38 [==============>...............] - ETA: 0s - loss: 0.1159 - accuracy: 0.9655
# Epoch 299: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9559 - val_loss: 1.0676 - val_accuracy: 0.8904
# Epoch 300/300
# 19/38 [==============>...............] - ETA: 0s - loss: 0.1536 - accuracy: 0.9523
# Epoch 300: val_accuracy did not improve from 0.90698
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1426 - accuracy: 0.9550 - val_loss: 1.0901 - val_accuracy: 0.8904

# %%
# Visualize the training history to see whether you're overfitting.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'TEST'], loc='lower right')
plt.show()

# %%
from keras.models import load_model

model = load_model("/content/drive/MyDrive/UGP23/dataset/Yoga_82_modified/weights_yoga82_angle&33kp.best_ann.hdf5")

# %%
model.evaluate(x_train, y_train)
# Out:
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 0.9858
# [0.04306092858314514, 0.985845148563385]

# %%
model.evaluate(x_val, y_val)
# Out:
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9957 - accuracy: 0.9070
# [0.9957137703895569, 0.9069767594337463]

# %%
model.evaluate(x_test, y_test)
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6743 - accuracy: 0.9202
# [0.6743196249008179, 0.9202127456665039]

# %%
y_pred = model.predict(x_test)
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %%
y_pred
# Out:
# array([[1.9539054e-04, 3.2196604e-10, 2.7132886e-11, ..., 1.9182589e-07,
#         2.4841249e-10, 4.1905298e-07],
#        [9.3205667e-01, 4.8236622e-04, 5.7121308e-04, ..., 4.0955832e-03,
#         3.6806487e-05, 5.0944407e-02],
#        [1.2506130e-08, 7.7368090e-19, 1.4253845e-12, ..., 9.9995941e-01,
#         1.1765119e-06, 6.3249658e-08],
#        ...,
#        [2.7291601e-15, 6.3969715e-20, 9.9999994e-01, ..., 1.0549522e-11,
#         2.4555345e-14, 7.2575097e-22],
#        [1.6310614e-10, 9.9969590e-01, 1.7921942e-06, ..., 3.7110152e-05,
#         3.5381129e-06, 7.6943195e-08],
#        [1.6118224e-14, 5.4711796e-16, 8.7123721e-05, ..., 4.0586991e-05,
#         1.7032567e-01, 4.0469781e-06]], dtype=float32)

# %%
y_pred.shape
# Out:
# (376, 9)

# %%
y_pred[0]
# Out:
# array([1.9539054e-04, 3.2196604e-10, 2.7132886e-11, 2.2670157e-11,
#        9.9969864e-01, 1.0507750e-04, 1.9182589e-07, 2.4841249e-10,
#        4.1905298e-07], dtype=float32)

# %%
y_test = np.argmax(y_test, axis=1)
y_pred = np.argmax(y_pred, axis=1)
y_pred
# Out:
# array([4, 0, 6, 0, 5, 4, 3, 7, 6, 3, 0, 6, 2, 3, 8, 0, 3, 3, 5, 6, 7, 6,
#        2, 0, 6, 6, 4, 6, 3, 6, 5, 2, 6, 8, 4, 4, 3, 0, 5, 4, 2, 6, 4, 6,
#        4, 0, 4, 2, 4, 2, 8, 2, 8, 6, 0, 3, 7, 5, 6, 5, 7, 8, 4, 4, 5, 3,
#        5, 3, 2, 4, 7, 2, 6, 4, 3, 3, 3, 8, 2, 7, 8, 7, 2, 1, 8, 3, 7, 7,
#        5, 6, 7, 5, 8, 4, 1, 7, 6, 5, 0, 6, 4, 4, 6, 0, 0, 4, 0, 8, 1, 6,
#        6, 4, 2, 6, 4, 1, 8, 6, 5, 8, 2, 3, 2, 3, 0, 6, 7, 6, 1, 4, 6, 6,
#        7, 1, 8, 8, 4, 2, 6, 7, 5, 6, 0, 8, 2, 2, 3, 0, 5, 8, 4, 5, 5, 8,
#        8, 4, 8, 8, 6, 0, 0, 1, 2, 7, 0, 6, 8, 5, 7, 6, 0, 7, 8, 3, 4, 4,
#        8, 7, 2, 5, 8, 2, 4, 5, 8, 4, 4, 0, 5, 4, 7, 6, 4, 5, 5, 8, 8, 6,
#        6, 6, 3, 7, 7, 4, 3, 6, 8, 2, 6, 4, 0, 6, 2, 6, 8, 8, 8, 7, 0, 4,
#        0, 8, 6, 6, 1, 6, 5, 5, 1, 6, 4, 4, 6, 0, 5, 5, 5, 2, 3, 6, 2, 8,
#        8, 5, 8, 1, 2, 6, 3, 3, 2, 7, 6, 6, 3, 7, 8, 1, 6, 3, 0, 8, 2, 5,
#        1, 6, 3, 4, 5, 8, 8, 5, 7, 0, 7, 6, 6, 8, 3, 7, 2, 4, 4, 7, 8, 6,
#        4, 8, 1, 6, 6, 5, 2, 1, 6, 6, 3, 6, 1, 1, 0, 4, 5, 5, 5, 4, 4, 5,
#        3, 6, 7, 6, 0, 2, 1, 3, 6, 4, 1, 6, 0, 4, 6, 3, 8, 4, 5, 4, 6, 1,
#        3, 3, 1, 5, 2, 4, 7, 8, 4, 4, 3, 6, 5, 4, 1, 5, 7, 1, 8, 8, 4, 8,
#        3, 4, 5, 7, 4, 3, 4, 1, 6, 2, 5, 6, 2, 3, 5, 5, 2, 7, 3, 5, 1, 2,
#        1, 5])

# %%
pose_test = [None] * y_test.size
pose_pred = [None] * y_pred.size

for i in range(len(y_test)):
    if(y_test[i]==0): pose_test[i] = 'Plank'           
    if(y_test[i]==1): pose_test[i] = 'Warrior_I'       
    if(y_test[i]==2): pose_test[i] = 'Standing_big_toe'     
    if(y_test[i]==3): pose_test[i] = 'Warrior_II'         
    if(y_test[i]==4): pose_test[i] = 'Cat_Cow'         
    if(y_test[i]==5): pose_test[i] = 'Child'            
    if(y_test[i]==6): pose_test[i] = 'Cobra'     
    if(y_test[i]==7): pose_test[i] = 'Tree'              
    if(y_test[i]==8): pose_test[i] = 'Downward-Facing_Dog'


for i in range(len(y_pred)):
    if(y_pred[i]==0): pose_pred[i] = 'Plank'                           
    if(y_pred[i]==1): pose_pred[i] = 'Warrior_I'                   
    if(y_pred[i]==2): pose_pred[i] = 'Standing_big_toe'     
    if(y_pred[i]==3): pose_pred[i] = 'Warrior_II'                      
    if(y_pred[i]==4): pose_pred[i] = 'Cat_Cow'                                              
    if(y_pred[i]==5): pose_pred[i] = 'Child'                                 
    if(y_pred[i]==6): pose_pred[i] = 'Cobra'                              
    if(y_pred[i]==7): pose_pred[i] = 'Tree'                                    
    if(y_pred[i]==8): pose_pred[i] = 'Downward-Facing_Dog'

# %%
confusion_matrix(pose_test, pose_pred)
# Out:
# array([[54,  1,  2,  1,  1,  0,  1,  0,  0],
#        [ 0, 36,  2,  1,  1,  0,  0,  0,  0],
#        [ 1,  4, 61,  0,  0,  2,  0,  0,  1],
#        [ 0,  1,  1, 45,  0,  0,  0,  0,  0],
#        [ 0,  0,  1,  0, 27,  0,  0,  0,  0],
#        [ 0,  2,  0,  0,  0, 29,  0,  0,  0],
#        [ 0,  1,  0,  0,  0,  1, 32,  0,  0],
#        [ 0,  0,  0,  0,  0,  2,  0, 25,  0],
#        [ 0,  1,  1,  0,  0,  1,  0,  0, 37]])

# %%
! pip install -q scikit-plot

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt

skplt.metrics.plot_confusion_matrix(pose_test, pose_pred, figsize=(10,10))

# Rotate x-axis labels by 90 degrees
plt.xticks(rotation=270)
plt.show()

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

f1_score(pose_test, pose_pred, average='weighted')
# Out:
# 0.9213778245661841

# %%
precision_score(pose_test, pose_pred, average='weighted')
# Out:
# 0.924952773277693

# %%
recall_score(pose_test, pose_pred, average='weighted')
# Out:
# 0.9202127659574468

# %%
from sklearn.metrics import f1_score

# Convert pose_val and pose_pred to numpy arrays
nppose_val = np.array(pose_test)
nppose_pred = np.array(pose_pred)

# Get a list of all unique labels
labels = np.unique(nppose_val)

# Calculate F1 score for each label
for label in labels:
    # Create a binary array indicating if the label matches the current label
    y_true = (nppose_val == label)
    y_pred = (nppose_pred == label)
    
    # Calculate F1 score
    f1 = f1_score(y_true, y_pred)
    
    # Print the F1 score for the current label
    print(f"F1 score for {label}: {f1}")
# Out:
# F1 score for Cat_Cow: 0.9391304347826087
# F1 score for Child: 0.8372093023255814
# F1 score for Cobra: 0.8905109489051095
# F1 score for Downward-Facing_Dog: 0.9574468085106385
# F1 score for Plank: 0.9473684210526316
# F1 score for Standing_big_toe: 0.8787878787878788
# F1 score for Tree: 0.955223880597015
# F1 score for Warrior_I: 0.9615384615384615
# F1 score for Warrior_II: 0.9487179487179489
